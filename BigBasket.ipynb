# %% [markdown]
# # BIG BASKET (TEST PROJECT)

# %% [markdown]
# # 1) Load Data set

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
bb=pd.read_csv('BigBasket Products.csv')

# %%
bb
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# # 2) Use head function to look for 1st 12 rows

# %%
bb.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %% [markdown]
# # 3) Get Description of the data Frame

# %%
bb.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %% [markdown]
# # 4) Find Information about the Data Frame.

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# # 5) Find out Top and Least sold product.

# %%
bb[bb.sale_price==bb.sale_price.max()]
# Out:
#       index    product          category    sub_category       brand  \
# 1249   1250  Beard Kit  Beauty & Hygiene  Men's Grooming  Uncle Tony
#
#       sale_price  market_price                type  rating  \
# 1249    112475.0        3300.0  Combos & Gift Sets     NaN
#
#                                             description
# 1249  The combination of a beard oil, a beard wash, ...

# %%
bb[bb.sale_price==bb.sale_price.min()]
# Out:
#        index       product             category        sub_category   brand  \
# 26976  26977  Curry Leaves  Fruits & Vegetables  Herbs & Seasonings  Fresho
#
#        sale_price  market_price                   type  rating  \
# 26976        2.45          15.0  Indian & Exotic Herbs     NaN
#
#                                              description
# 26976  With dark green and glossy appearance, curry l...

# %% [markdown]
# # 6) Measureming Discount on a certain item.

# %%
bb['Discount']=((bb['market_price']-bb['sale_price'])/bb['market_price']/100)

# %%
bb
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# # 7) Find out the missing Values From the Data Set.

# %%
bb.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# Discount           6
# dtype: int64

# %%
bb.brand=bb.brand.bfill()

# %%
bb.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              0
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# Discount           6
# dtype: int64

# %%
bb.sale_price=bb.sale_price.bfill()

# %%
bb.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
bb.isna().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
bb.sale_price.mean()
# Out:
# 334.59751515151515

# %%
bb.market_price.mean()
# Out:
# 382.05666448920346

# %% [markdown]
# # 8) Find out the outliers from the data set according to the columns & fill with the mean.

# %%
sns.boxplot(bb.sale_price)
# Out:
# <Axes: >

# %%
sns.boxplot(bb)
# Out:
# <Axes: >

# %%
Q1,Q3=bb.sale_price.quantile([0.25,0.75])

# %%
Q1,Q3
# Out:
# (95.0, 359.0)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 264.0

# %%
UL=Q3+1.5*IQR
LL=Q1+-1.5*IQR

# %%
UL,LL
# Out:
# (755.0, -301.0)

# %%
bb[bb.sale_price>UL]
# Out:
#        index                                            product  \
# 8          9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 47        48                              Colour Catcher Sheets
# 51        52                                        Peach Syrup
# 69        70             Padded Harness - 3/4 inch, Grey Colour
# 91        92    Hard Anodised Ezee-Pour Saucepan With Lid - L88
# ...      ...                                                ...
# 27498  27499            Juicer - Fruit & Vegetable, Light Green
# 27505  27506                                 Virgin Coconut Oil
# 27514  27515                     Verge & Sheer Perfume For Pair
# 27538  27539  Quista Pro Advanced Whey Protein Formula forti...
# 27542  27543                    Embellish Skin Lightening Serum
#
#                        category            sub_category            brand  \
# 8              Beauty & Hygiene               Hair Care       StBotanica
# ...

# %%
bb[bb.sale_price>UL]['sale_price'].median()
# Out:
# 1170.0

# %%
bb.sale_price=np.where(bb.sale_price>UL,UL,bb.sale_price)

# %%
bb
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
sns.boxplot(bb.sale_price,orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(bb.sale_price)
# Out:
# <Axes: >

# %% [markdown]
# # 9) Creat A Plot or visualiztion.

# %%
plt.scatter(bb.sale_price,bb.market_price)
plt.show()

# %%
plt.hist(bb.market_price)
plt.show()

# %%
sns.distplot(bb.market_price)
plt.show()

# %% [markdown]
# # ******Thank You*******
